# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelAngelSP29/Probabilidad-y-estad-stica-/blob/main/Unidad%201/U1_practica%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y Estadistica**
#
# # **Undad 1**
#
# **Practica 3: tabla de frecuencia y regla de Sturges**
# ## Docente : Dr.Jose gabriel Rodriguez Rivas
# ## Alumno : Miguel angel Solis Perez 25041713

# %%
#basado en el libro estadistic para administacion pgina 12
#creamos una lista vacia para genear 100 numeros alaeatorios que represntan la edad de las personas
import random
edades = []
#hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
  #Generamos un numero aleatorio con la funcion randbit y lo guardamos en la variable
  #numero aleatorio
  numero_aleatorio = random.randint(18,70)
  #Agregamos el numero añeatorio ala lista e valores
  edades.append(numero_aleatorio)
#imprimimos la lista de edades
print(edades)
# Out:
# [18, 40, 41, 18, 52, 61, 39, 37, 65, 42, 35, 35, 42, 33, 30, 21, 42, 54, 21, 63, 28, 18, 22, 69, 70, 58, 47, 22, 52, 41, 27, 68, 48, 69, 19, 46, 62, 23, 41, 70, 58, 21, 58, 34, 47, 69, 69, 34, 27, 23, 29, 37, 33, 63, 54, 18, 64, 66, 58, 28, 52, 50, 26, 33, 63, 33, 23, 37, 50, 34, 51, 56, 36, 25, 65, 32, 52, 20, 62, 25, 45, 61, 37, 36, 38, 56, 57, 41, 46, 61, 44, 37, 63, 29, 68, 65, 57, 68, 36, 23]

# %%
import pandas as pd

# %%
#crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns = ['Edad'])
df.head()
# Out:
#    Edad
# 0    18
# 1    40
# 2    41
# 3    18
# 4    52

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 1     18           4
# 34    19           1
# 40    20           1
# 13    21           3
# 21    22           2
# 8     23           4
# 16    25           2
# 37    26           1
# 22    27           2
# 26    28           2
# 29    29           2
# 32    30           1
# 39    32           1
# 4     33           4
# 15    34           3
# 19    35           2
# 14    36           3
# 0     37           5
# 42    38           1
# 31    39           1
# 30    40           1
# 3     41           4
# 9     42           3
# 43    44           1
# 41    45           1
# 25    46           2
# 23    47           2
# 33    48           1
# 28    50           2
# 36    51           1
# 2     52           4
# 27    54           2
# 18    56           2
# 17    57           2
# 5     58           4
# 11    61           3
# 24    62           2
# 7     63           4
# 38    64           1
# 10    65           3
# 35    66           1
# 12    68           3
# 6     69           4
# 20    70           2

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 1     18           4           0.04
# 34    19           1           0.01
# 40    20           1           0.01
# 13    21           3           0.03
# 21    22           2           0.02
# 8     23           4           0.04
# 16    25           2           0.02
# 37    26           1           0.01
# 22    27           2           0.02
# 26    28           2           0.02
# 29    29           2           0.02
# 32    30           1           0.01
# 39    32           1           0.01
# 4     33           4           0.04
# 15    34           3           0.03
# 19    35           2           0.02
# 14    36           3           0.03
# 0     37           5           0.05
# 42    38           1           0.01
# 31    39           1           0.01
# 30    40           1           0.01
# 3     41           4           0.04
# 9     42           3           0.03
# 43    44           1           0.01
# 41    45           1           0.01
# 25    46           2           0.02
# 23    47           2           0.02
# 33    48           1           0.01
# 28    50           2           0.02
# 36    51           1           0.01
# 2     52           4           0.04
# 27    54           2           0.02
# 18    56           2           0.02
# 17    57           2           0.02
# 5     58           4           0.04
# 11    61           3           0.03
# 24    62           2           0.02
# 7     63           4           0.04
# 38    64           1           0.01
# 10    65           3           0.03
# 35    66           1           0.01
# 12    68           3           0.03
# 6     69           4           0.04
# 20    70           2           0.02

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 1     18           4           0.04              4.0
# 34    19           1           0.01              1.0
# 40    20           1           0.01              1.0
# 13    21           3           0.03              3.0
# 21    22           2           0.02              2.0
# 8     23           4           0.04              4.0
# 16    25           2           0.02              2.0
# 37    26           1           0.01              1.0
# 22    27           2           0.02              2.0
# 26    28           2           0.02              2.0
# 29    29           2           0.02              2.0
# 32    30           1           0.01              1.0
# 39    32           1           0.01              1.0
# 4     33           4           0.04              4.0
# 15    34           3           0.03              3.0
# 19    35           2           0.02              2.0
# 14    36           3           0.03              3.0
# 0     37           5           0.05              5.0
# 42    38           1           0.01              1.0
# 31    39           1           0.01              1.0
# 30    40           1           0.01              1.0
# 3     41           4           0.04              4.0
# 9     42           3           0.03              3.0
# 43    44           1           0.01              1.0
# 41    45           1           0.01              1.0
# 25    46           2           0.02              2.0
# 23    47           2           0.02              2.0
# 33    48           1           0.01              1.0
# 28    50           2           0.02              2.0
# 36    51           1           0.01              1.0
# 2     52           4           0.04              4.0
# 27    54           2           0.02              2.0
# 18    56           2           0.02              2.0
# 17    57           2           0.02              2.0
# 5     58           4           0.04              4.0
# 11    61           3           0.03              3.0
# 24    62           2           0.02              2.0
# 7     63           4           0.04              4.0
# 38    64           1           0.01              1.0
# 10    65           3           0.03              3.0
# 35    66           1           0.01              1.0
# 12    68           3           0.03              3.0
# 6     69           4           0.04              4.0
# 20    70           2           0.02              2.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 1     18           4           0.04              4.0               4
# 34    19           1           0.01              1.0               5
# 40    20           1           0.01              1.0               6
# 13    21           3           0.03              3.0               9
# 21    22           2           0.02              2.0              11
# 8     23           4           0.04              4.0              15
# 16    25           2           0.02              2.0              17
# 37    26           1           0.01              1.0              18
# 22    27           2           0.02              2.0              20
# 26    28           2           0.02              2.0              22
# 29    29           2           0.02              2.0              24
# 32    30           1           0.01              1.0              25
# 39    32           1           0.01              1.0              26
# 4     33           4           0.04              4.0              30
# 15    34           3           0.03              3.0              33
# 19    35           2           0.02              2.0              35
# 14    36           3           0.03              3.0              38
# 0     37           5           0.05              5.0              43
# 42    38           1           0.01              1.0              44
# 31    39           1           0.01              1.0              45
# 30    40           1           0.01              1.0              46
# 3     41           4           0.04              4.0              50
# 9     42           3           0.03              3.0              53
# 43    44           1           0.01              1.0              54
# 41    45           1           0.01              1.0              55
# 25    46           2           0.02              2.0              57
# 23    47           2           0.02              2.0              59
# 33    48           1           0.01              1.0              60
# 28    50           2           0.02              2.0              62
# 36    51           1           0.01              1.0              63
# 2     52           4           0.04              4.0              67
# 27    54           2           0.02              2.0              69
# 18    56           2           0.02              2.0              71
# 17    57           2           0.02              2.0              73
# 5     58           4           0.04              4.0              77
# 11    61           3           0.03              3.0              80
# 24    62           2           0.02              2.0              82
# 7     63           4           0.04              4.0              86
# 38    64           1           0.01              1.0              87
# 10    65           3           0.03              3.0              90
# 35    66           1           0.01              1.0              91
# 12    68           3           0.03              3.0              94
# 6     69           4           0.04              4.0              98
# 20    70           2           0.02              2.0             100

# %%
# Importamos la librería math de funciones matemáticas
import math

# %%
# Volvemos a usar la lista edades
print(edades)
# Out:
# [18, 40, 41, 18, 52, 61, 39, 37, 65, 42, 35, 35, 42, 33, 30, 21, 42, 54, 21, 63, 28, 18, 22, 69, 70, 58, 47, 22, 52, 41, 27, 68, 48, 69, 19, 46, 62, 23, 41, 70, 58, 21, 58, 34, 47, 69, 69, 34, 27, 23, 29, 37, 33, 63, 54, 18, 64, 66, 58, 28, 52, 50, 26, 33, 63, 33, 23, 37, 50, 34, 51, 56, 36, 25, 65, 32, 52, 20, 62, 25, 45, 61, 37, 36, 38, 56, 57, 41, 46, 61, 44, 37, 63, 29, 68, 65, 57, 68, 36, 23]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     18
# 1     40
# 2     41
# 3     18
# 4     52
# ..   ...
# 95    65
# 96    57
# 97    68
# 98    36
# 99    23
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
K = int( 1 + math.log2(n))
print("Valor de n = ", n , " \nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencia
tabla_frecuencia = pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (32.857, 40.286]    20
# 1    (62.571, 70.0]    18
# 2  (17.947, 25.429]    17
# 3  (55.143, 62.571]    13
# 4  (40.286, 47.714]    13
# 5  (47.714, 55.143]    10
# 6  (25.429, 32.857]     9

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.947, 25.429]    17
# 6  (25.429, 32.857]     9
# 0  (32.857, 40.286]    20
# 4  (40.286, 47.714]    13
# 5  (47.714, 55.143]    10
# 3  (55.143, 62.571]    13
# 1    (62.571, 70.0]    18

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 2  (17.947, 25.429]    17      0.17       17.0       17         0.17
# 6  (25.429, 32.857]     9      0.09        9.0       26         0.26
# 0  (32.857, 40.286]    20      0.20       20.0       46         0.46
# 4  (40.286, 47.714]    13      0.13       13.0       59         0.59
# 5  (47.714, 55.143]    10      0.10       10.0       69         0.69
# 3  (55.143, 62.571]    13      0.13       13.0       82         0.82
# 1    (62.571, 70.0]    18      0.18       18.0      100         1.00
#
#    Frec Porc Ac
# 2          17.0
# 6          26.0
# 0          46.0
# 4          59.0
# 5          69.0
# 3          82.0
# 1         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
