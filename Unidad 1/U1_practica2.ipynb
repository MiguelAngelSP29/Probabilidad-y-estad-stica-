# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelAngelSP29/Probabilidad-y-estad-stica-/blob/main/Unidad%201/U1_practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# ## Unidad 1
#
# ### **Practica 2, Maximo, mnimo , Rango y  dispersion de datos.**
#
# ### facilitador: Dr.Jose Gabriel Rodriguez Rivas*
#
# ## Alumno: Miguel Angel Solis Perez 25041713

# %%
import random
import matplotlib.pyplot as plt    #Libreria para graficar
from statistics import *

# %%
#Generar numeros aleatoros que representan la rouccion
# En mtrs de la tela de 100 dias
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)

# %%
#Generar numeros aleatoros que representan la rouccion
# En mtrs de la tela de 100 dias
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round(random.uniform(70,100),2)
  fabrica1.append(numero_aleatorio2)

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)

print("Estadistica descriptiva de la fabrica 1 \n","Media =",media1,"\n Mediana =", mediana1,"\n Moda = ", moda1, "\n Maximo =", maximo1, "\n Minimo =",minimo1,"\n Rango =", rango1)

print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  Media = 80.21525
#  Mediana = 80.815
#  Moda =  56.71
#  Maximo = 99.84
#  Minimo = 50.82
#  Rango = 49.02
# 12.79101282082119

# %%
from statistics import mean, median, mode, stdev

# %%
from statistics import mean, median, mode, stdev

# Datos de ejemplo
fabrica2 = [12, 15, 14, 12, 18, 20, 12, 16]

maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)

print("Estadistica descriptiva de la fabrica 2 \n","Media =",media2,"\n Mediana =", mediana2,"\n Moda = ", moda2, "\n Maximo =", maximo2, "\n Minimo =",minimo2,"\n Rango =", rango2)

print(desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  Media = 14.875
#  Mediana = 14.5
#  Moda =  12
#  Maximo = 20
#  Minimo = 12
#  Rango = 8
# 2.997022331772464

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1,bins=10, alpha=0.2,color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_Fabrica1, color='black',linestyle='dashed', linewidth=2, label=f'Desv. estandar={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_Fabrica1, color='black',linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma de la fabrica 1')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1208/4205978458.py in <cell line: 0>()
#       4 plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
#       5 plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
# ----> 6 plt.axvline(media1 - desviacion_estandar_Fabrica1, color='black',linestyle='dashed', linewidth=2, label=f'Desv. estandar={desviacion_estandar_fabrica1:.2f}')
#       7 plt.axvline(media1 + desviacion_estandar_Fabrica1, color='black',linestyle='dashed', linewidth=2)
#       8
#
# NameError: name 'desviacion_estandar_Fabrica1' is not defined

# %% [markdown]
# ##**Interpretacion**

# %%
import seaborn as sns
sns.histplot (x = fabrica1, kde = True, kde_kws={"color":"black","linewidth":2})
